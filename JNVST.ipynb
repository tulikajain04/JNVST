# %%
#import sys
#print(sys.executable)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
from  plotly.offline import iplot
import  plotly.express as px
import plotly as py 
import plotly.graph_objects as go
import plotly.tools as tls 
import cufflinks as cf
from dbfread import DBF
#!pip install dbfread
#!pip install libc.so.6
#dbf = DBF('D:\JNV\jnvst2021.dbf')
def load_data(path):
    dbf = DBF(path)
    return dbf
import warnings
warnings.filterwarnings("ignore")

#from app import app

import dash
import dash_bootstrap_components as dbc
from dash import html,dcc,Input,Output
from datetime import datetime,date

# %%
data_2021=load_data(r'D:\JNV\jnvst2021.dbf')
data_2019=load_data('D:\JNV\jnvst2019.dbf')
data_2020_wb=load_data('D:\JNV\jnvst2020wb.dbf')
data_2020_sb=load_data('D:\JNV\jnvst2020sb.dbf')

# %%
data_2021_df= pd.DataFrame(iter(data_2021))

# %%
data_2019_df= pd.DataFrame(iter(data_2019))

# %%
data_2020_wb= pd.DataFrame(iter(data_2020_wb))

# %%
data_2020_sb= pd.DataFrame(iter(data_2020_sb))

# %%
data_2020_wb['Season']='Winter'
data_2020_sb['Season']='Summer'

# %%
data_2020_df=pd.concat([data_2020_sb,data_2020_wb])

# %%
data2019=data_2019_df.copy()
data2020=data_2020_df.copy()
data2021=data_2021_df.copy()

# %%
data2021=data2021.drop(['ST','DT','BL','SEX', 'CAT', 'AREA','ABS'], axis=1)
#data_2021=data_2021.drop(['ABS'], axis=1)

data2019=data2019.drop(['ST','DT','BL','SEX_CD', 'CAT_CD', 'AREA_CD','DD','MM','YY','ABS'], axis=1)
#data_2019=data_2019.drop(['DD','MM','YY'], axis=1)
#data_2019=data_2019.drop(['ABS'], axis=1)

data2019.rename(columns={'SEX':'SEX_F','CAT':'CAT_F','PH':'PH_F','AREA':'AREA_F','MED':"MEDIUM"},inplace=True)

data2019['PRE'][data2019['PRE']!="P"]='A'

data2020['PRE'][data2020['PRE']!="P"]='A'

data2021['PRE'][data2021['PRE']!="P"]='A'

#print(f" ** Memory usage of the file - {sum(data_2020_sb.memory_usage()) * 0.000001} MB for {len(data_2020_sb.index)} Rows")

data2019['YEAR']='2019'
data2020['YEAR']='2020'
data2021['YEAR']='2021'

# %%
data2020=data2020.drop(['ST','DT','BL','SEX', 'CAT', 'AREA','ABS'], axis=1)

# %%
data2020.rename(columns={'PH_CD':'PH_F'}, inplace=True)

# %%
#data2019.columns
# Out:
# Index(['STNM', 'DTNM', 'BLNM', 'CN', 'SEX_F', 'CAT_F', 'AREA_F', 'HANDI',
#        'PH_CD', 'DOB', 'MEDIUM', 'PRE', 'MAT', 'ARI', 'LNG', 'TOT', 'ELIG',
#        'RANK', 'SELE', 'YEAR'],
#       dtype='object')

# %%
#data2020.columns
# Out:
# Index(['STNM', 'DTNM', 'BLNM', 'CN', 'HANDI', 'SEX_F', 'CAT_F', 'PH_F',
#        'AREA_F', 'DOB', 'MEDIUM', 'PRE', 'MAT', 'ARI', 'LNG', 'TOT', 'ELIG',
#        'RANK', 'SELE', 'Season', 'YEAR'],
#       dtype='object')

# %%
#data2021.columns
# Out:
# Index(['STNM', 'DTNM', 'BLNM', 'CN', 'HANDI', 'SEX_F', 'CAT_F', 'PH_F',
#        'AREA_F', 'DOB', 'MEDIUM', 'PRE', 'MAT', 'ARI', 'LNG', 'TOT', 'ELIG',
#        'RANK', 'SELE', 'YEAR'],
#       dtype='object')

# %%
#data2020['AREA'].unique()
# Out:
# array(['R', 'U'], dtype=object)

# %%
data=pd.concat([data2019,data2020,data2021])

# %%
data['CAT_F']=data['CAT_F'].replace({'G':'GENERAL',"O":"OBC","T":"ST","C":"SC",'GEN':'GENERAL','GENRAL':'GENERAL'})
data['AREA_F']=data['AREA_F'].replace({'R':'RURAL',"U":"URBAN"})

# %%
data['SEX_F']=data['SEX_F'].replace({'B':'Male',"G":"FEMALE"})

# %%
data['HANDI'].unique()
# Out:
# array(['', 'PH', 'VH', 'HI', 'VI'], dtype=object)

# %%
#data.rename(columns={'STNM': 'STATE', 'DTNM':'DISTRICT', 'AREA_F':'AREA','CAT_F': 'Category','HANDI':'Disability','ELIG':'ELIGIBILITY', 'BLNM':'BLOCK'}, inplace=True)
data.rename(columns={'STATE': 'STNM', 'DISTRICT':'DTNM', 'AREA':'AREA_F','Category': 'CAT_F','Disability':'HANDI','ELIGIBILITY':'ELIG', 'BLOCK':'BLNM'}, inplace=True)

# %%
#data.rename(columns={'SEX_F':'GENDER'}, inplace=True)
data.rename(columns={'GENDER':'SEX_F'}, inplace=True)

# %%
data[data['AREA']=='R']
# Out:
#                   STNM        DTNM                  BLNM  CN   SEX_F    CAT_F  \
# 0       ANDHRA PRADESH   ANANTAPUR           DHARMAVARAM  01  FEMALE  GENERAL
# 1       ANDHRA PRADESH   ANANTAPUR           KADIRI EAST  02  FEMALE      OBC
# 2       ANDHRA PRADESH   ANANTAPUR           KADIRI EAST  03    MALE  GENERAL
# 3       ANDHRA PRADESH   ANANTAPUR           DHARMAVARAM  02  FEMALE      OBC
# 4       ANDHRA PRADESH   ANANTAPUR           KALYANADURG  03  FEMALE      OBC
# ...                ...         ...                   ...  ..     ...      ...
# 116677     WEST BENGAL  DARJEELING         SUKHIAPOKHARI  01    MALE  GENERAL
# 116679     WEST BENGAL  DARJEELING  DARJEELING PUL BAZAR  01    MALE  GENERAL
# 116680     WEST BENGAL  DARJEELING           KALIMPONG-I  01    MALE  GENERAL
# 116682       KARNATAKA     BELLARY             SIRUGUPPA  02    MALE      OBC
# 116684       KARNATAKA    BAGALKOT              BAGALKOT  03    MALE       SC
#
# ...

# %%
data['AREA_F']
# Out:
# 0          RURAL
# 1          URBAN
# 2          URBAN
# 3          RURAL
# 4          RURAL
#            ...
# 2417004    RURAL
# 2417005    RURAL
# 2417006    RURAL
# 2417007    RURAL
# 2417008    URBAN
# Name: AREA_F, Length: 7458023, dtype: object

# %%
data.groupby(["YEAR","STATE","DISTRICT","AREA"])["DISTRICT"].count().reset_index(name="COUNT")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 data.groupby(["YEAR","STATE","DISTRICT","AREA"])["DISTRICT"].count().reset_index(name="COUNT")
#
# File ~\Anaconda\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
# ...

# %%
data['HANDI']=data['HANDI'].replace({' ':" Not Disabled",'0':" Not Disabled",'VI': " Visual Impared", 'VH': " Visual Disabled",'PH':'Physical Disabled', 'HI':'Hearing Disabled'})

# %%
data['BLNM'].unique()
# Out:
# array(['HINDUPUR', 'RAYADURG', 'TADIPATRI', ..., 'INDAS',
#        'BHEEMADEVARAPALLY', 'GHANPUR STATION'], dtype=object)

# %%
# data=pd.read_json("data2020.json")
#data=pd.read_csv("data.csv",encoding="utf8")

#data.drop(labels="Unnamed: 0",axis=1,inplace=True)
#data['YEAR'] = np.random.randint(2019,2022, data.shape[0])
#data.YEAR=data.YEAR.astype("str")

df_dist=(data.groupby(["YEAR","STNM","DTNM","AREA_F"])["DTNM"].count().reset_index(name="COUNT"))

df_sc=(data.groupby(["YEAR","STNM","DTNM","CAT_F"])["CAT_F"].count().reset_index(name="COUNT"))

df_gender=(data.groupby(["YEAR","STNM","DTNM","SEX_F"])["SEX_F"].count().reset_index(name="COUNT"))

df_disability=(data.groupby(["YEAR","STNM","DTNM","HANDI"])["HANDI"].count().reset_index(name="COUNT"))

data2=data.groupby(["YEAR","STNM","DTNM","AREA_F"])["AREA_F"].count().reset_index(name="COUNT")

data["DOB"]=pd.to_datetime(data["DOB"],errors='coerce')
#data["Today"]=date.today()
now = pd.Timestamp('now')
data['DOB'] = pd.to_datetime(data['DOB'], format='%m%d%y')    # 1
data['DOB'] = data['DOB'].where(data['DOB'] < now, data['DOB'] -  np.timedelta64(100, 'Y'))   # 2
data['age'] = (now - data['DOB']).astype('<m8[Y]')
df_age=data.groupby(["YEAR","STNM","DTNM","age"])["age"].count().reset_index(name="COUNT")

data["PRE"]=data["PRE"].replace(np.nan,"",regex=True)
#data["ABS"]=data["ABS"].replace(np.nan,"",regex=True)
#data["ATTENDENCE"]=data["PRE"]+data["ABS"]
attend_dict={"P":"Present","A":"Absent"}
data["ATTENDENCE"]=data["PRE"].map(attend_dict)
df_attend=data.groupby(["YEAR","STNM","DTNM","ATTENDENCE"])["ATTENDENCE"].count().reset_index(name="COUNT")


present_E=data[(data["ATTENDENCE"]=="Present") &(data['ELIG']=='E')]
high_atnd=present_E.groupby(["YEAR","DTNM","PRE"])['DTNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=False)




######-------------------------------------FRONTEND WEB_PAGE-----------------------------------------------------------------------


app=dash.Dash(__name__,external_stylesheets=[dbc.themes.BOOTSTRAP],
            meta_tags=[{'name': 'viewport', 'content': 'width=device-width, initial-scale=1'}])


app.layout= dbc.Container([
                dbc.Row([
                    dbc.Col([
                        dbc.Row([                          #Title row
                            dbc.Col([
                                html.H3("JNVST Data Analysis",style={"textAlign":"center","color":"#f59d05","fontWeight":"bold",
                                                        "text-decoration": "underline"})
                            ])
                            ],justify="around", className="mb-3 mt-1"),
                        dbc.Row([                          # drop-down rows
                            dbc.Col([
                                dcc.Dropdown(id="df-year",
                                 options=[ {'label': i, 'value': i} for i in data['YEAR'].unique()],
                                 value="",style={"backgroundColor":'white','fontSize': 20,
                                                           "color":"#f59d05"}) #"fontWeight":"bold"}),
                            ]),
                            dbc.Col([
                                dcc.Dropdown(id="df-location",            # STate dropdown
                                 options=[ {'label': i, 'value': i} for i in data['STNM'].unique()],# + [{'label': 'Select all', 'value': 'allID'}],
                                 value="",
                                 style={"backgroundColor":'white','fontSize': 20,
                                                           "color":"#f59d05"}) #,"fontWeight":"bold"}),
                            ]),
                            
                            dbc.Col([
                                dcc.Dropdown(id="df-district",
                                 options=[], #+ [{'label': 'Select all', 'value': 'allID'}],
                                 value=[],#'Please select Data Center',
                                 multi=False,
                                 placeholder="Select District",
                                 style={"backgroundColor":'white','fontSize': 20,
                                                           "color":"#f59d05"}) #"fontWeight":"bold"}),
                            ])
                        ],justify="around", className="mb-3 mt-3"),

                        dbc.Row([
                            dbc.Col([
                                html.H5("Rural:",style={'textAlign': 'center',"fontWeight":"bold",'fontSize': 20,#"margin-top":"10px",
                                                                             "color":"#f59d05","text-decoration": "underline"})
                                ],width=1,className="mt-0"),
                            dbc.Col([
                                html.H4(id="rural_kpi", children="", style={'textAlign': 'center',"fontWeight":"bold",
                                                                             'color': '#f59d05',#"background":"#BF8B67",
                                                                             'fontSize': 25,"text-decoration": "underline"
                                                                             }),
                                ],width=1),
                            dbc.Col([
                                html.H5("Urban:",style={'textAlign': 'center',"fontWeight":"bold",'fontSize': 20,#"margin-top":"10px",
                                                                             'color': '#f59d05',"text-decoration": "underline"})
                                ],width=1.,className="mt-0"),
                            dbc.Col([
                                 html.H4(id="urban_kpi", children="" ,style={'textAlign': 'center',"fontWeight":"bold",'color': '#f59d05',
                                                                        'fontSize': 20,"text-decoration": "underline"}),
                                ],width=1),
                            dbc.Col([
                                html.H5("TOT_Marks:",style={'textAlign': 'center',"fontWeight":"bold",'fontSize': 20,#"margin-top":"10px",
                                                                             "color":"#f59d05","text-decoration": "underline"})
                                ],width=2,className="mt-0"),
                            dbc.Col([
                                html.H4(id="N_M_kpi", children="", style={'textAlign': 'center',"fontWeight":"bold",
                                                                             'color': '#f59d05',#"background":"#BF8B67",
                                                                             'fontSize': 20,"text-decoration": "underline"
                                                                             }),
                                ],width=1),
                            dbc.Col([
                                html.H5("MAT_Marks:",style={'textAlign': 'center',"fontWeight":"bold",'fontSize': 20,#"margin-top":"10px",
                                                                             'color': '#f59d05',"text-decoration": "underline"})
                                ],width=2,className="mt-0"),
                            dbc.Col([
                                 html.H4(id="M_M_kpi", children="" ,style={'textAlign': 'center',"fontWeight":"bold",'color': '#f59d05',
                                                                        'fontSize': 20,"text-decoration": "underline"}),
                                ],width=1),
                        ], className="mb-1 mt-1"),
                    
                        dbc.Row([          #chart row1
                            dbc.Col([
                                #  html.P("DISTRICT COUNT",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph1"),
                                ],width=4),
                        
                            dbc.Col([
                                #  html.P("GENDER DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph2"),
                            ],width=4),
                            dbc.Col([
                                #  html.P("CATEGORY",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph3"),
                            ],width=4), 
                        ],justify="around",className="mt-2 mb-2"),
                        dbc.Row([          #chart row2
                            dbc.Col([
                                # html.P("DISABILIY DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph4"),
                               ],width=4),
                        
                            dbc.Col([
                                #  html.P("Rural/Urban DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph5"),
                            ],width=4),
                            dbc.Col([
                                #  html.P("AGE DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph6"),
                             ],width=4), 
                        ],justify="around",className="mt-2 mb-2"),
                        dbc.Row([          #chart row3
                            dbc.Col([
                                # html.P("DISABILIY DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph7"),
                               ],width=6),
                        
                            dbc.Col([
                                #  html.P("Rural/Urban DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph8"),
                            ],width=6),
                        ],justify="around",className="mt-2 mb-2"),
                        dbc.Row([          #chart row4
                            dbc.Col([
                                # html.P("DISABILIY DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph9"),
                               ],width=4),
                        
                            dbc.Col([
                                #  html.P("Rural/Urban DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph10"),
                            ],width=4),
                            dbc.Col([
                                #  html.P("AGE DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph11"),
                             ],width=4), 
                        ],justify="around",className="mt-2 mb-2"),

                        dbc.Row([          #chart row5
                            dbc.Col([
                                # html.P("DISABILIY DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph12"),
                               ],width=4),
                        
                            dbc.Col([
                                #  html.P("Rural/Urban DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph13"),
                            ],width=4),
                            dbc.Col([
                                #  html.P("AGE DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph14"),
                             ],width=4), 
                        ],justify="around",className="mt-2 mb-2"),

                        dbc.Row([          #chart row6
                            dbc.Col([
                                # html.P("DISABILIY DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph15"),
                               ],width=4),
                        
                            dbc.Col([
                                #  html.P("Rural/Urban DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph16"),
                            ],width=4),
                            dbc.Col([
                                #  html.P("AGE DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph17"),
                             ],width=4), 
                        ],justify="around",className="mt-2 mb-2"),
                    ])
                ])
                   
],fluid=True,style={"background":"white"})                             


#######--------------------------------------------------BACKEND LOGIC----------------------------------------------------------
@app.callback(
    Output("df-location","options"),
    [Input("df-year","value"),
    ]
)

def dist_opt(year):
    dff1=data[(data["YEAR"]==year)]
    return [{'label': s,'value': s} for s in dff1["STNM"].unique()]


@app.callback(
    Output("df-location","value"),
    Input("df-year","options"),
)

def dist_values(all_options_s):
    return [x["value"] for x in all_options_s]




@app.callback(
    Output("df-district","options"),
    [Input("df-location","value"),
    ]
)

def dist_opt(location):
    dff=data[(data["STNM"]==location)]
    return [{'label': d,'value': d} for d in dff["DTNM"].unique()]


@app.callback(
    Output("df-district","value"),
    Input("df-district","options"),
)

def dist_values(all_options):
    return [x["value"] for x in all_options]





@app.callback(
    [
    Output("My_graph1","figure"),
    Output("My_graph2","figure"),
    Output("My_graph3","figure"),
    Output("My_graph4","figure"),
    Output("My_graph5","figure"),
    Output("My_graph6","figure"),
    Output("My_graph7","figure"),
    Output("My_graph8","figure"),
    Output("My_graph9","figure"),
    ],
    [ Input("df-year","value"),
    Input("df-location","value"),
    Input("df-district","value"),
    ]
)


def update_graph(year,location,district):

    df_gender=(data.groupby(["YEAR","STNM","DTNM","SEX_F"])["SEX_F"].count().reset_index(name="COUNT"))
    graph1=df_gender[(df_gender["YEAR"]==year) & (df_gender["STNM"]==location) & (df_gender["DTNM"]==district)]
    fig1 = px.bar(graph1,x="SEX_F",y="COUNT",color_discrete_sequence=px.colors.sequential.Sunset)
    #fig1.update_traces(marker_color='#f7d074')  
    fig1.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                     title={'text': "Gender Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>GENDER</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12)),)


    df_age=data.groupby(["YEAR","STNM","DTNM","age"])["age"].count().reset_index(name="COUNT")
    graph2=df_age[(df_age["YEAR"]==year) & (df_age["STNM"]==location) & (df_age["DTNM"]==district)]    
    fig2 = px.bar(graph2,x="age",y="COUNT",color_discrete_sequence=px.colors.sequential.Sunset)
    #fig2.update_traces(marker_color='#f7d074') 
    fig2.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                      title={'text': "Age Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>AGE</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12)),)     



    df_sc=(data.groupby(["YEAR","STNM","DTNM","CAT_F"])["CAT_F"].count().reset_index(name="COUNT"))
    graph3=df_sc[(df_sc["YEAR"]==year) & (df_sc["STNM"]==location) & (df_sc["DTNM"]==district)]
    fig3 = px.pie(graph3, values='COUNT', names='CAT_F',color_discrete_sequence=px.colors.sequential.Sunset)
    fig3.update_layout(height=350,
                title={'text': "Social Category Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                font=dict(family='sans-serif',color='#632626',size=16))


    df_attend=data.groupby(["YEAR","STNM","DTNM","ATTENDENCE"])["ATTENDENCE"].count().reset_index(name="COUNT")
    graph4=df_attend[(df_attend["YEAR"]==year) & (df_attend["STNM"]==location) & (df_attend["DTNM"]==district)]  
    fig4 = px.pie(graph4, values='COUNT', names='ATTENDENCE',color_discrete_sequence=px.colors.sequential.Sunset) 
    fig4.update_layout(height=250,
                title={'text': "Attendence Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                font=dict(family='sans-serif',color='#632626',size=16)) 
    

    df_disability=(data.groupby(["YEAR","STNM","DTNM","HANDI"])["HANDI"].count().reset_index(name="COUNT"))
    graph6=df_disability[(df_disability["YEAR"]==year) & (df_disability["STNM"]==location) & (df_disability["DTNM"]==district)]
    fig6 = px.pie(graph6, values='COUNT', names='HANDI',color_discrete_sequence=px.colors.sequential.Sunset) 
    fig6.update_layout(height=350,
                title={'text': "Disability Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                font=dict(family='sans-serif',color='#632626',size=16))    

    data2=data.groupby(["YEAR","STNM","DTNM","AREA_F"])["AREA_F"].count().reset_index(name="COUNT")
    graph5=data2[(data2["YEAR"]==year) & (data2["STNM"]==location) & (data2["DTNM"]==district)]
    fig5=px.pie(graph5,values='COUNT', names='AREA_F',color_discrete_sequence=px.colors.sequential.Sunset)
    fig5.update_layout(height=350,
               title={'text': "Area Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'}, 
                font=dict(family='sans-serif',color='#632626',size=16))

    urban_s=data[data["AREA_F"]=="URBAN"]
    u_block=urban_s.groupby(["YEAR","STNM","DTNM","BLNM"])['BLNM'].count().reset_index(name="COUNT").sort_values(['COUNT'], ascending=True) 
    graph7=u_block[(u_block["YEAR"]==year) & (u_block["STNM"]==location) & (u_block["DTNM"]==district)]    
    fig7 = px.bar(graph7,y="BLNM",x="COUNT",color_discrete_sequence=px.colors.sequential.Sunset)
    #fig7.update_traces(marker_color='#f7d074') ,
    fig7.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                      #title={'text': "URBAN School by Block",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>URBAN School by Block</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12))) 


    rural_s=data[data["AREA_F"]=="RURAL"]
    r_block=rural_s.groupby(["YEAR","STNM","DTNM","BLNM"])['BLNM'].count().reset_index(name="COUNT").sort_values(['COUNT'], ascending=True)
    graph8=r_block[(r_block["YEAR"]==year) & (r_block["STNM"]==location) & (r_block["DTNM"]==district)]    
    fig8 = px.bar(graph8,y="BLNM",x="COUNT",color_discrete_sequence=px.colors.sequential.Sunset)
    #fig8.update_traces(marker_color='#f7d074') ,
    fig8.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                      #title={'text': "RURAL School by Block",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>RURAL School by Block</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12))) 


    df_e=data.groupby(["YEAR","STNM","DTNM","AREA_F","ELIG"])["ELIG"].count().reset_index(name="COUNT")
    graph9=df_e[(df_e["YEAR"]==year) & (df_e["STNM"]==location) & (df_e["DTNM"]==district)]
    fig9 = px.bar(graph9,y="COUNT",x="AREA_F",color_discrete_sequence=px.colors.sequential.Sunset)
    #fig9.update_traces(marker_color='#f7d074') ,
    fig9.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                      title={'text': "Block-Wise School",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>ELIGIBILITY</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12)))

    rural_data=data[(data["AREA_F"]=="RURAL")]
    rural_state=rural_data[(rural_data["YEAR"]==year) & (rural_data["STNM"]==location) & (rural_data["DTNM"]==district)]
    kpi_r=rural_state["AREA_F"].count()

    urban_data=data[(data["AREA_F"]=="URBAN")]
    urban_state=urban_data[(urban_data["YEAR"]==year) & (urban_data["STNM"]==location) & (urban_data["DTNM"]==district)]
    kpi_u=urban_state["AREA_F"].count()



    return fig1,fig2,fig3,fig4,fig6,fig5,fig7,fig8,fig9



#@app.callback(
#    [Output("rural_kpi","children"),
 #   Output("urban-kpi","children")],
#    [Input("df-location","value"),
 #   Input("df-year","value"),
 #   ]
#)

#def kpi(year,location):
#    rural_data=data[(data["AREA_F"]=="RURAL")]
#    rural_state=rural_data[(rural_data["YEAR"]==year) & (rural_data["STNM"]==location)]
#    kpi_r=rural_state["AREA_F"].count()

#    urban_data=data[(data["AREA_F"]=="URBAN")]
#    urban_state=urban_data[(urban_data["YEAR"]==year) & (urban_data["STNM"]==location)]
#    kpi_u=urban_state["AREA_F"].count()

#    return kpi_r,kpi_u

 

## Top and bottom 10 district by candidate attendence

@app.callback(
    [Output("My_graph10","figure"),
    Output("My_graph11","figure"),
    Output("My_graph12","figure"),
    Output("My_graph13","figure"),
    ],
    Input("df-year","value"),
)

def dist_atndc(year):
    high_atnd=present_E.groupby(["YEAR","DTNM","PRE"])['DTNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=False)
    graph10=high_atnd[(high_atnd["YEAR"]==year)][:10]
    fig10=px.bar(graph10,x="Count",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig10.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                      title={'text': "Top 10 District by Attendence",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>ATTENDENCE COUNT</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12))) 

    low_atnd=present_E.groupby(["YEAR","DTNM","PRE"])['DTNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=True)
    graph11=low_atnd[(low_atnd["YEAR"]==year)][:10]
    fig11=px.bar(graph11,x="Count",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig11.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    title={'text': "Bottom 10 District by Attendence",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>ATTENDENCE COUNT</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12))) 

                        
    present_data=data[data["ATTENDENCE"]=="Present"]
    high_apprd=present_data.groupby(["YEAR","DTNM","PRE"])['DTNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=False)
    graph12=high_apprd[(high_apprd["YEAR"]==year)][:10]
    fig12=px.bar(graph12,x="Count",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig12.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    title={'text': "Top 10 District Appeared",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>APPEARED COUNT</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12))) 
                        
    low_apprd=present_data.groupby(["YEAR","DTNM","PRE"])['DTNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=True)
    graph13=low_apprd[(low_apprd["YEAR"]==year)][:10]
    fig13=px.bar(graph13,x="Count",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig13.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    title={'text': "Bottom 10 District Appeared",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>APPEARED COUNT</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12)))

    

    return fig10,fig11,fig12,fig13


@app.callback(
    [Output("My_graph14","figure"),
    Output("My_graph15","figure")],
    [Input("df-year","value"),
    Input("df-location","value")]
)

def update_marks(year,location):

    present_data=data[data["ATTENDENCE"]=="Present"]
    avg_mrks_A=present_data.groupby(["YEAR","STNM","DTNM"])["TOT"].mean().reset_index(name="Avg_marks").sort_values("Avg_marks",ascending=False)
    graph14=avg_mrks_A[(avg_mrks_A["YEAR"]==year) & (avg_mrks_A["STNM"]==location)]
    fig14=px.bar(graph14,x="Avg_marks",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig14.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    title={'text': "Avg. Appeared Candidate Marks",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>AVG. MARKS</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12)))


    elig_data=data[data["ELIG"]=="E"]
    Avg_mrks_S=elig_data.groupby(["YEAR","STNM","DTNM"])["TOT"].mean().reset_index(name="Avg_marks_S").sort_values("Avg_marks_S",ascending=False)
    graph15=Avg_mrks_S[(Avg_mrks_S["YEAR"]==year) & (Avg_mrks_S["STNM"]==location)]
    fig15=px.bar(graph15,x="Avg_marks_S",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig15.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    title={'text': "Avg. Selected Candidate Marks",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>AVG. MARKS</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12)))
    
    
   

    return fig14,fig15

#@app.callback(
#    [Output("N_M_kpi","children"),
#    Output("M_M_kpi","children")],
#    [Input("df-year","value")]
#    )

#def marks_kpi(year):
#    elig_data=data[data["ELIG"]=="E"]

#    N_avg_mrks=elig_data.groupby("YEAR")["TOT"].mean().reset_index()
#    N_avg=N_avg_mrks[N_avg_mrks["YEAR"]==year].mean()
#    Nat_avg=N_avg

#    M_avg_mrks=elig_data.groupby("YEAR")["MAT"].mean().reset_index()
#    M_avg=M_avg_mrks[M_avg_mrks["YEAR"]==year].mean()
#    Mat_avg=M_avg

#    return Nat_avg,Mat_avg



if __name__ == "__main__":
      app.run_server(debug=False,port=8005)
# Out:
# KeyboardInterrupt

# %%
df_dist=(data.groupby(["YEAR","STNM","DTNM","AREA_F"])["DTNM"].count().reset_index(name="COUNT"))

df_sc=(data.groupby(["YEAR","STNM","DTNM","CAT_F"])["CAT_F"].count().reset_index(name="COUNT"))

df_gender=(data.groupby(["YEAR","STNM","DTNM","SEX_F"])["SEX_F"].count().reset_index(name="COUNT"))

df_disability=(data.groupby(["YEAR","STNM","DTNM","HANDI"])["HANDI"].count().reset_index(name="COUNT"))

data2=data.groupby(["YEAR","STNM","DTNM","AREA_F"])["AREA_F"].count().reset_index(name="COUNT")

data["DOB"]=pd.to_datetime(data["DOB"],errors='coerce')
#data["Today"]=date.today()
now = pd.Timestamp('now')
data['DOB'] = pd.to_datetime(data['DOB'], format='%m%d%y')    # 1
data['DOB'] = data['DOB'].where(data['DOB'] < now, data['DOB'] -  np.timedelta64(100, 'Y'))   # 2
data['age'] = (now - data['DOB']).astype('<m8[Y]')
df_age=data.groupby(["YEAR","STNM","DTNM","age"])["age"].count().reset_index(name="COUNT")

data["PRE"]=data["PRE"].replace(np.nan,"",regex=True)
#data["ABS"]=data["ABS"].replace(np.nan,"",regex=True)
#data["ATTENDENCE"]=data["PRE"]+data["ABS"]
attend_dict={"P":"Present","A":"Absent"}
data["ATTENDENCE"]=data["PRE"].map(attend_dict)
df_attend=data.groupby(["YEAR","STNM","DTNM","ATTENDENCE"])["ATTENDENCE"].count().reset_index(name="COUNT")


present_E=data[(data["ATTENDENCE"]=="Present") &(data['ELIG']=='E')]
high_atnd=present_E.groupby(["YEAR","DTNM","PRE"])['DTNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=False)

######-------------------------------------FRONTEND WEB_PAGE-----------------------------------------------------------------------


app=dash.Dash(__name__,external_stylesheets=[dbc.themes.BOOTSTRAP],
            meta_tags=[{'name': 'viewport', 'content': 'width=device-width, initial-scale=1'}])


app.layout= dbc.Container([
                dbc.Row([
                    dbc.Col([
                        dbc.Row([                          #Title row
                            dbc.Col([
                                html.H3("JNVST Data Analysis",style={"textAlign":"center","color":"#f59d05","fontWeight":"bold",
                                                        "text-decoration": "underline"})
                            ])
                            ],justify="around", className="mb-3 mt-1"),
                        dbc.Row([                          # drop-down rows
                            dbc.Col([
                                dcc.Dropdown(id="df-year",
                                 options=[ {'label': i, 'value': i} for i in data['YEAR'].unique()],
                                 value="",style={"backgroundColor":'white','fontSize': 20,
                                                           "color":"#f59d05"}) #"fontWeight":"bold"}),
                            ]),
                            dbc.Col([
                                dcc.Dropdown(id="df-location",            # STate dropdown
                                 options=[ {'label': i, 'value': i} for i in data['STNM'].unique()],# + [{'label': 'Select all', 'value': 'allID'}],
                                 value="",
                                 style={"backgroundColor":'white','fontSize': 20,
                                                           "color":"#f59d05"}) #,"fontWeight":"bold"}),
                            ]),
                            
                            dbc.Col([
                                dcc.Dropdown(id="df-district",
                                 options=[], #+ [{'label': 'Select all', 'value': 'allID'}],
                                 value=[],#'Please select Data Center',
                                 multi=False,
                                 placeholder="Select District",
                                 style={"backgroundColor":'white','fontSize': 20,
                                                           "color":"#f59d05"}) #"fontWeight":"bold"}),
                            ])
                        ],justify="around", className="mb-3 mt-3"),

                        dbc.Row([
                            dbc.Col([
                                html.H5("Rural:",style={'textAlign': 'center',"fontWeight":"bold",'fontSize': 25,#"margin-top":"10px",
                                                                             "color":"#f59d05","text-decoration": "underline"})
                                ],width=2,className="mt-0"),
                            dbc.Col([
                                html.H4(id="rural_kpi", children="", style={'textAlign': 'left',"fontWeight":"bold",
                                                                             'color': '#f59d05',#"background":"#BF8B67",
                                                                             'fontSize': 25,"text-decoration": "underline"
                                                                             }),
                                ],width=2),
                            dbc.Col([

                            ],width=4),
                            dbc.Col([
                                html.H5("Urban:",style={'textAlign': 'center',"fontWeight":"bold",'fontSize': 25,#"margin-top":"10px",
                                                                             'color': '#f59d05',"text-decoration": "underline"})
                                ],width=2,className="mt-0"),
                            dbc.Col([
                                 html.H4(id="urban_kpi", children="" ,style={'textAlign': 'left',"fontWeight":"bold",'color': '#f59d05',
                                                                        'fontSize': 25,"text-decoration": "underline"}),
                                ],width=2),
                            
                        ],justify="around", className="mb-1 mt-1"),

                        dbc.Row([
                            dbc.Col([
                                html.H5("National Avg.Marks:",style={'textAlign': 'center',"fontWeight":"bold",'fontSize': 25,#"margin-top":"10px",
                                                                             "color":"#ffe577","text-decoration": "underline"})
                                ],width=2,className="mt-0"),
                            dbc.Col([
                                html.H4(id="N_M_kpi", children="", style={'textAlign': 'left',"fontWeight":"bold",
                                                                             'color': '#ffe577',#"background":"#BF8B67",
                                                                             'fontSize': 25,"text-decoration": "underline"
                                                                             }),
                                ],width=1),
                            dbc.Col([
                                html.H5("Avg.Mental Ability Marks:",style={'textAlign': 'center',"fontWeight":"bold",'fontSize': 25,#"margin-top":"10px",
                                                                             'color': '#fec051',"text-decoration": "underline"})
                                ],width=2,className="mt-0"),
                            dbc.Col([
                                 html.H4(id="M_M_kpi", children="" ,style={'textAlign': 'left',"fontWeight":"bold",'color': '#fec051',
                                                                        'fontSize': 25,"text-decoration": "underline"}),
                                ],width=1),
                                dbc.Col([
                                html.H5("Avg.Airthmetic Marks:",style={'textAlign': 'center',"fontWeight":"bold",'fontSize': 25,#"margin-top":"10px",
                                                                             "color":"#ff8967","text-decoration": "underline"})
                                ],width=2,className="mt-0"),
                            dbc.Col([
                                html.H4(id="ari_kpi", children="", style={'textAlign': 'left',"fontWeight":"bold",
                                                                             'color': '#ff8967',#"background":"#BF8B67",
                                                                             'fontSize': 25,"text-decoration": "underline"
                                                                             }),
                                ],width=1),
                            dbc.Col([
                                html.H5("Avg.Language Marks:",style={'textAlign': 'center',"fontWeight":"bold",'fontSize': 25,#"margin-top":"10px",
                                                                             'color': '#fd6051',"text-decoration": "underline"})
                                ],width=2,className="mt-0"),
                            dbc.Col([
                                 html.H4(id="lang_kpi", children="" ,style={'textAlign': 'left',"fontWeight":"bold",'color': '#fd6051',
                                                                        'fontSize': 25,"text-decoration": "underline"}),
                                ],width=1),
                        ],justify="around", className="mb-1 mt-1"),
                    
                        dbc.Row([          #chart row1
                            dbc.Col([
                                #  html.P("DISTRICT COUNT",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph1"),
                                ],width=4),
                        
                            dbc.Col([
                                #  html.P("GENDER DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph2"),
                            ],width=4),
                            dbc.Col([
                                #  html.P("CATEGORY",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph3"),
                            ],width=4), 
                        ],justify="around",className="mt-2 mb-2"),
                        dbc.Row([          #chart row2
                            dbc.Col([
                                # html.P("DISABILIY DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph4"),
                               ],width=4),
                        
                            dbc.Col([
                                #  html.P("Rural/Urban DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph5"),
                            ],width=4),
                            dbc.Col([
                                #  html.P("AGE DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph6"),
                             ],width=4), 
                        ],justify="around",className="mt-2 mb-2"),
                        dbc.Row([          #chart row3
                            dbc.Col([
                                # html.P("DISABILIY DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph7"),
                               ],width=6),
                        
                            dbc.Col([
                                #  html.P("Rural/Urban DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph8"),
                            ],width=6),
                        ],justify="around",className="mt-2 mb-2"),
                        dbc.Row([          #chart row4
                            dbc.Col([
                                # html.P("DISABILIY DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph9"),
                               ],width=4),
                        
                            dbc.Col([
                                #  html.P("Rural/Urban DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph10"),
                            ],width=4),
                            dbc.Col([
                                #  html.P("AGE DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph11"),
                             ],width=4), 
                        ],justify="around",className="mt-2 mb-2"),

                        dbc.Row([          #chart row5
                            dbc.Col([
                                # html.P("DISABILIY DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph12"),
                               ],width=4),
                        
                            dbc.Col([
                                #  html.P("Rural/Urban DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph13"),
                            ],width=4),
                            dbc.Col([
                                #  html.P("AGE DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph14"),
                             ],width=4), 
                        ],justify="around",className="mt-2 mb-2"),

                        dbc.Row([          #chart row6
                            dbc.Col([
                                # html.P("DISABILIY DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph15"),
                               ],width=4),
                        
                            dbc.Col([
                                #  html.P("Rural/Urban DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph16"),
                            ],width=4),
                            dbc.Col([
                                #  html.P("AGE DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph17"),
                             ],width=4), 
                        ],justify="around",className="mt-2 mb-2"),
                        dbc.Row([          #chart row7
                            dbc.Col([
                                # html.P("DISABILIY DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph18"),
                               ],width=4),
                        
                            dbc.Col([
                                #  html.P("Rural/Urban DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph19"),
                            ],width=4),
                            dbc.Col([
                                #  html.P("AGE DISTRIBUTION",style={"backgroundColor":'white','textAlign': 'center',
                                #                            "color":"#010915",
                                #                            "fontWeight":"bold"}),
                                        dcc.Graph(id="My_graph20"),
                             ],width=4), 
                        ],justify="around",className="mt-2 mb-2"),
                    ])
                ])
                   
],fluid=True,style={"background":"white"})                             


#######--------------------------------------------------BACKEND LOGIC----------------------------------------------------------
@app.callback(
    Output("df-location","options"),
    [Input("df-year","value"),
    ]
)

def dist_opt(year):
    dff1=data[(data["YEAR"]==year)]
    return [{'label': s,'value': s} for s in dff1["STNM"].unique()]


@app.callback(
    Output("df-location","value"),
    Input("df-year","options"),
)

def dist_values(all_options_s):
    return [x["value"] for x in all_options_s]




@app.callback(
    Output("df-district","options"),
    [Input("df-location","value"),
    ]
)

def dist_opt(location):
    dff=data[(data["STNM"]==location)]
    return [{'label': d,'value': d} for d in dff["DTNM"].unique()]


@app.callback(
    Output("df-district","value"),
    Input("df-district","options"),
)

def dist_values(all_options):
    return [x["value"] for x in all_options]





@app.callback(
    [
    Output("My_graph1","figure"),
    Output("My_graph2","figure"),
    Output("My_graph3","figure"),
    Output("My_graph4","figure"),
    Output("My_graph5","figure"),
    Output("My_graph6","figure"),
    Output("My_graph7","figure"),
    Output("My_graph8","figure"),
    Output("My_graph9","figure"),
    ],
    [ Input("df-year","value"),
    Input("df-location","value"),
    Input("df-district","value"),
    ]
)


def update_graph(year,location,district):

    df_gender=(data.groupby(["YEAR","STNM","DTNM","SEX_F"])["SEX_F"].count().reset_index(name="COUNT"))
    graph1=df_gender[(df_gender["YEAR"]==year) & (df_gender["STNM"]==location) & (df_gender["DTNM"]==district)]
    fig1 = px.bar(graph1,x="SEX_F",y="COUNT",color_discrete_sequence=px.colors.sequential.Sunset)
    #fig1.update_traces(marker_color='#f7d074')  
    fig1.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                     title={'text': "Gender Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>GENDER</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12)),)


    df_age=data.groupby(["YEAR","STNM","DTNM","age"])["age"].count().reset_index(name="COUNT")
    graph2=df_age[(df_age["YEAR"]==year) & (df_age["STNM"]==location) & (df_age["DTNM"]==district)]    
    fig2 = px.bar(graph2,x="age",y="COUNT",color_discrete_sequence=px.colors.sequential.Sunset)
    #fig2.update_traces(marker_color='#f7d074') 
    fig2.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                      title={'text': "Age Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>AGE</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12)),)     



    df_sc=(data.groupby(["YEAR","STNM","DTNM","CAT_F"])["CAT_F"].count().reset_index(name="COUNT"))
    graph3=df_sc[(df_sc["YEAR"]==year) & (df_sc["STNM"]==location) & (df_sc["DTNM"]==district)]
    fig3 = px.pie(graph3, values='COUNT', names='CAT_F',color_discrete_sequence=px.colors.sequential.Sunset)
    fig3.update_layout(height=350,
                title={'text': "Social Category Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                font=dict(family='sans-serif',color='#632626',size=16))


    df_attend=data.groupby(["YEAR","STNM","DTNM","ATTENDENCE"])["ATTENDENCE"].count().reset_index(name="COUNT")
    graph4=df_attend[(df_attend["YEAR"]==year) & (df_attend["STNM"]==location) & (df_attend["DTNM"]==district)]  
    fig4 = px.pie(graph4, values='COUNT', names='ATTENDENCE',color_discrete_sequence=px.colors.sequential.Sunset) 
    fig4.update_layout(height=350,
                title={'text': "Attendence Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                font=dict(family='sans-serif',color='#632626',size=16)) 
    

    df_disability=(data.groupby(["YEAR","STNM","DTNM","HANDI"])["HANDI"].count().reset_index(name="COUNT"))
    graph6=df_disability[(df_disability["YEAR"]==year) & (df_disability["STNM"]==location) & (df_disability["DTNM"]==district)]
    fig6 = px.pie(graph6, values='COUNT', names='HANDI',color_discrete_sequence=px.colors.sequential.Sunset) 
    fig6.update_layout(height=350,
                title={'text': "Disability Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                font=dict(family='sans-serif',color='#632626',size=14))    

    data2=data.groupby(["YEAR","STNM","DTNM","AREA_F"])["AREA_F"].count().reset_index(name="COUNT")
    graph5=data2[(data2["YEAR"]==year) & (data2["STNM"]==location) & (data2["DTNM"]==district)]
    fig5=px.pie(graph5,values='COUNT', names='AREA_F',color_discrete_sequence=px.colors.sequential.Sunset)
    fig5.update_layout(height=350,
               title={'text': "Area Distribution",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'}, 
                font=dict(family='sans-serif',color='#632626',size=16))

    urban_s=data[data["AREA_F"]=="URBAN"]
    u_block=urban_s.groupby(["YEAR","STNM","DTNM","BLNM"])['BLNM'].count().reset_index(name="COUNT").sort_values(['COUNT'], ascending=True) 
    graph7=u_block[(u_block["YEAR"]==year) & (u_block["STNM"]==location) & (u_block["DTNM"]==district)]    
    fig7 = px.bar(graph7,y="BLNM",x="COUNT",color_discrete_sequence=px.colors.sequential.Sunset)
    #fig7.update_traces(marker_color='#f7d074') ,
    fig7.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                      title={'text': "Block-wise School",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>BLOCK_WISE_URBAN</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12))) 


    rural_s=data[data["AREA_F"]=="RURAL"]
    r_block=rural_s.groupby(["YEAR","STNM","DTNM","BLNM"])['BLNM'].count().reset_index(name="COUNT").sort_values(['COUNT'], ascending=True)
    graph8=r_block[(r_block["YEAR"]==year) & (r_block["STNM"]==location) & (r_block["DTNM"]==district)]    
    fig8 = px.bar(graph8,y="BLNM",x="COUNT",color_discrete_sequence=px.colors.sequential.Sunset)
    #fig8.update_traces(marker_color='#f7d074') ,
    fig8.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                      title={'text': "Block-wise School",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>BLOCK_WISE_RURAL</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12))) 


    df_e=data.groupby(["YEAR","STNM","DTNM","AREA_F","ELIG"])["ELIG"].count().reset_index(name="COUNT")
    graph9=df_e[(df_e["YEAR"]==year) & (df_e["STNM"]==location) & (df_e["DTNM"]==district)]
    fig9 = px.bar(graph9,y="COUNT",x="AREA_F",color_discrete_sequence=px.colors.sequential.Sunset)
    #fig9.update_traces(marker_color='#f7d074') ,
    fig9.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                      #title={'text': "Selected Candidates by Area Wise",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>Selected Candidates by Area Wise</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12)))





    return fig1,fig2,fig3,fig4,fig6,fig5,fig7,fig8,fig9



@app.callback(
    [Output("rural_kpi","children"),
    Output("urban_kpi","children")],
    [
    Input("df-year","value"),
    ]
)

def kpi(year):
    rural_s=data[(data["AREA_F"]=="RURAL")]
    rural_state=rural_s[(rural_s["YEAR"]==year)]
    kpi_r=rural_state["AREA_F"].count()

    urban_s=data[(data["AREA_F"]=="URBAN")]
    urban_state=urban_s[(urban_s["YEAR"]==year)]
    kpi_u=urban_state["AREA_F"].count()

    return kpi_r,kpi_u

 

## Top and bottom 10 district by candidate attendence

@app.callback(
    [Output("My_graph10","figure"),
    Output("My_graph11","figure"),
    Output("My_graph12","figure"),
    Output("My_graph13","figure"),
    ],
    Input("df-year","value"),
)

def dist_atndc(year):
    high_atnd=present_E.groupby(["YEAR","DTNM","PRE"])['DTNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=False)
    graph10=high_atnd[(high_atnd["YEAR"]==year)][:10]
    fig10=px.bar(graph10,x="Count",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig10.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                      title={'text': "Top 10 District by Attendence",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                      hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                      font=dict(family='sans-serif',color='#632626',size=16), 
                      xaxis=dict(title='<b>ATTENDENCE COUNT</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                      yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                 linewidth=1,ticks='outside',
                                 tickfont=dict(color='#BF8B67', size=12))) 

    low_atnd=present_E.groupby(["YEAR","DTNM","PRE"])['DTNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=True)
    graph11=low_atnd[(low_atnd["YEAR"]==year)][:10]
    fig11=px.bar(graph11,x="Count",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig11.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    title={'text': "Bottom 10 District by Attendence",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>ATTENDENCE COUNT</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12))) 

                        
    present_data=data[data["ATTENDENCE"]=="Present"]
    high_apprd=present_data.groupby(["YEAR","DTNM","PRE"])['DTNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=False)
    graph12=high_apprd[(high_apprd["YEAR"]==year)][:10]
    fig12=px.bar(graph12,x="Count",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig12.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    title={'text': "Top 10 District Appeared",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>APPEARED COUNT</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12))) 
                        
    low_apprd=present_data.groupby(["YEAR","DTNM","PRE"])['DTNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=True)
    graph13=low_apprd[(low_apprd["YEAR"]==year)][:10]
    fig13=px.bar(graph13,x="Count",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig13.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    title={'text': "Bottom 10 District Appeared",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>APPEARED COUNT</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12)))

    

    return fig10,fig11,fig12,fig13


@app.callback(
    [
    Output("My_graph14","figure"),
    Output("My_graph15","figure"),
    Output("My_graph16","figure"),
    Output("My_graph17","figure"),
    Output("My_graph18","figure"),
    Output("My_graph19","figure"),
    Output("My_graph20","figure")],
    [Input("df-year","value"),
    Input("df-location","value")]
)

def update_marks(year,location):
    
    present_data=data[(data["ATTENDENCE"]=="Present")]
    admn_present_data=present_data[ (present_data["ELIG"]=="E")]
    block_sel_adm=admn_present_data.groupby(["YEAR","DTNM","BLNM","PRE"])['BLNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=False)
    graph14=block_sel_adm[(block_sel_adm["YEAR"]==year)][:10]
    fig14=px.bar(graph14,x="Count",y="BLNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig14.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    title={'text': "More Student for Admission",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>More Student for Admission</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12)))
    
    n_present_data=present_data[(present_data["ELIG"]=="")]
    block_sel_adm_n=n_present_data.groupby(["YEAR","DTNM","BLNM","PRE"])['BLNM'].count().reset_index(name='Count').sort_values(['Count'], ascending=False)
    graph15=block_sel_adm_n[(block_sel_adm_n["YEAR"]==year)][:10]
    fig15=px.bar(graph15,x="Count",y="BLNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig15.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    title={'text': "No More Student for Admission",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>No More Student for Admission</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12)))

    
    avg_mrks_A=present_data.groupby(["YEAR","STNM","DTNM"])["TOT"].mean().reset_index(name="Avg_marks").sort_values("Avg_marks",ascending=False)
    graph16=avg_mrks_A[(avg_mrks_A["YEAR"]==year) & (avg_mrks_A["STNM"]==location)]
    fig16=px.bar(graph16,x="Avg_marks",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig16.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                   # title={'text': "Avg. Appeared Candidate Marks",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>Total Average Marks of Appeared candidates</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12)))
    
    
    
    elig_data=data[data["ELIG"]=="E"]
    Avg_mrks_S=elig_data.groupby(["YEAR","STNM","DTNM"])["TOT"].mean().reset_index(name="Avg_marks_S").sort_values("Avg_marks_S",ascending=False)
    graph17=Avg_mrks_S[(Avg_mrks_S["YEAR"]==year) & (Avg_mrks_S["STNM"]==location)]
    fig17=px.bar(graph17,x="Avg_marks_S",y="DTNM",color_discrete_sequence=px.colors.sequential.Sunset)
    fig17.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    #title={'text': "Avg. National Marks",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>National Average Marks of qualified Candidates</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12)))


    
    M_avg_mrks=elig_data.groupby(["YEAR","STNM","DTNM"])["MAT"].mean().reset_index()
    graph18=M_avg_mrks[(M_avg_mrks["YEAR"]==year )& (M_avg_mrks["STNM"]==location)]
    fig18=px.bar(graph18,y="DTNM",x="MAT",color_discrete_sequence=px.colors.sequential.Sunset)
    fig18.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    #title={'text': "Avg. Mat Marks",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>Average Marks in Mental Ability</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12)))

    A_avg_mrks=elig_data.groupby(["YEAR","STNM","DTNM"])["ARI"].mean().reset_index()
    graph19=A_avg_mrks[(A_avg_mrks["YEAR"]==year) & (A_avg_mrks["STNM"]==location)]
    fig19=px.bar(graph19,y="DTNM",x="ARI",color_discrete_sequence=px.colors.sequential.Sunset)
    fig19.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    #title={'text': "Avg. Ari Marks",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>Average Marks in Airthmetic</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12)))

    L_avg_mrks=elig_data.groupby(["YEAR","STNM","DTNM"])["LNG"].mean().reset_index()
    graph20=L_avg_mrks[(L_avg_mrks["YEAR"]==year) & (L_avg_mrks["STNM"]==location)]
    fig20=px.bar(graph20,y="DTNM",x="LNG",color_discrete_sequence=px.colors.sequential.Sunset)
    fig20.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
                    #title={'text': "Average Language Marks",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                    hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
                    font=dict(family='sans-serif',color='#632626',size=16), 
                    xaxis=dict(title='<b>Average Marks in  Language</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
                                linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
                    yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
                                linewidth=1,ticks='outside',
                                tickfont=dict(color='#BF8B67', size=12)))

    return fig14,fig15,fig16,fig17,fig18,fig19,fig20

    

@app.callback(
    [Output("N_M_kpi","children"),
    Output("M_M_kpi","children"),
    Output("ari_kpi","children"),
    Output("lang_kpi","children")],
    [Input("df-year","value")]
    )

def marks_kpi(year):
    elig_data=data[data["ELIG"]=="E"]

    N_avg_mrks=elig_data.groupby("YEAR")["TOT"].mean().reset_index()
    N_avg=N_avg_mrks[(N_avg_mrks["YEAR"]==year)].mean()[1]
    tot=round(N_avg,2)
   

    M_avg_mrks=elig_data.groupby("YEAR")["MAT"].mean().reset_index()
    M_avg=M_avg_mrks[M_avg_mrks["YEAR"]==year].mean()[1]
    mat=round(M_avg,2)

    A_avg_mrks=elig_data.groupby("YEAR")["ARI"].mean().reset_index()
    A_avg=A_avg_mrks[A_avg_mrks["YEAR"]==year].mean()[1]
    ari=round(A_avg,2)

    L_avg_mrks=elig_data.groupby("YEAR")["LNG"].mean().reset_index()
    L_avg=L_avg_mrks[L_avg_mrks["YEAR"]==year].mean()[1]
    lang=round(L_avg,2)
    
    return tot,mat,ari,lang


# @app.callback(
#     [Output("My_graph16","figure"),
#     Output("My_graph17","figure"),
#     Output("My_graph18","figure"),
#     Output("My_graph19","figure")],
#     [Input("df-year","value"),
#     Input("df-location","value")]
#     )

# def marks_graph(year,location):

#     elig_data=data[data["ELIG"]=="E"]
#     N_avg_mrks=elig_data.groupby(["YEAR","STNM","DTNM"])["TOT"].mean().reset_index()
#     graph_16=N_avg_mrks[(N_avg_mrks["YEAR"]==year) & ([N_avg_mrks["STNM"]==location])]
#     fig16=px.bar(graph_16,y="DTNM",x="TOT",color_discrete_sequence=px.colors.sequential.Sunset)
#     fig16.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
#                     title={'text': "Avg. National Marks",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
#                     hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
#                     font=dict(family='sans-serif',color='#632626',size=16), 
#                     xaxis=dict(title='<b>AVG. MARKS</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
#                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
#                     yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
#                                 linewidth=1,ticks='outside',
#                                 tickfont=dict(color='#BF8B67', size=12)))
   

#     M_avg_mrks=elig_data.groupby(["YEAR","STNM","DTNM"])["MAT"].mean().reset_index()
#     graph17=M_avg_mrks[(M_avg_mrks["YEAR"]==year )& (M_avg_mrks["STNM"]==location)]
#     fig17=px.bar(graph17,y="DTNM",x="MAT",color_discrete_sequence=px.colors.sequential.Sunset)
#     fig17.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
#                     title={'text': "Avg. Mat Marks",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
#                     hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
#                     font=dict(family='sans-serif',color='#632626',size=16), 
#                     xaxis=dict(title='<b>AVG. MARKS</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
#                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
#                     yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
#                                 linewidth=1,ticks='outside',
#                                 tickfont=dict(color='#BF8B67', size=12)))

#     A_avg_mrks=elig_data.groupby(["YEAR","STNM","DTNM"])["ARI"].mean().reset_index()
#     graph18=A_avg_mrks[(A_avg_mrks["YEAR"]==year) & (A_avg_mrks["STNM"]==location)]
#     fig18=px.bar(graph18,y="DTNM",x="ARI",color_discrete_sequence=px.colors.sequential.Sunset)
#     fig18.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
#                     title={'text': "Avg. Ari Marks",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
#                     hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
#                     font=dict(family='sans-serif',color='#632626',size=16), 
#                     xaxis=dict(title='<b>AVG. MARKS</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
#                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
#                     yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
#                                 linewidth=1,ticks='outside',
#                                 tickfont=dict(color='#BF8B67', size=12)))

#     L_avg_mrks=elig_data.groupby(["YEAR","STNM","DTNM"])["LANG"].mean().reset_index()
#     graph19=L_avg_mrks[(L_avg_mrks["YEAR"]==year) & (L_avg_mrks["STNM"]==location)]
#     fig19=px.bar(graph19,y="DTNM",x="LANG",color_discrete_sequence=px.colors.sequential.Sunset)
#     fig19.update_layout(height=350,hovermode="closest",plot_bgcolor="white",paper_bgcolor="white",
#                     title={'text': "Avg. Lang Marks",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
#                     hoverlabel=dict( bgcolor="#BF8B67",font_size=12),
#                     font=dict(family='sans-serif',color='#632626',size=16), 
#                     xaxis=dict(title='<b>AVG. MARKS</b>', color='#BF8B67',showline=True,showgrid=False,showticklabels=True,
#                                 linecolor='#BF8B67',linewidth=1,ticks='outside',tickfont=dict(color='#BF8B67',size=12)),
#                     yaxis=dict(title="",color='#BF8B67',showline=True,showgrid=False,showticklabels=True,linecolor='#BF8B67',
#                                 linewidth=1,ticks='outside',
#                                 tickfont=dict(color='#BF8B67', size=12)))
    

#     return fig16,fig17,fig18,fig19




if __name__ == "__main__":
      app.run_server(debug=False,port=8855)
# Out:
# Dash is running on http://127.0.0.1:8855/
#
# Dash is running on http://127.0.0.1:8855/
#
# Dash is running on http://127.0.0.1:8855/
#
# Dash is running on http://127.0.0.1:8855/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8855/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Jul/2022 15:46:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 15:46:13] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 15:46:13] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 15:46:13] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 15:46:13] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2022 15:46:13] "POST /_dash-update-component HTTP/1.1" 200 -
# ...
